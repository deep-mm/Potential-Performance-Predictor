# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Dataset/data.csv')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['BusinessTravel'] = le.fit_transform(df['BusinessTravel'])
df['Department'] = le.fit_transform(df['Department'])
df['EducationField'] = le.fit_transform(df['EducationField'])
df['Attrition'] = le.fit_transform(df['Attrition'])
df['Gender'] = le.fit_transform(df['Gender'])
df['JobRole'] = le.fit_transform(df['JobRole'])
df['MaritalStatus'] = le.fit_transform(df['MaritalStatus'])
df['OverTime'] = le.fit_transform(df['OverTime'])
df['Over18'] = le.fit_transform(df['Over18'])
df['JobSatisfaction'] = le.fit_transform(df['JobSatisfaction'])
df['EnvironmentSatisfaction'] = le.fit_transform(df['EnvironmentSatisfaction'])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 35 columns]

# %%
#check for Nan values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.106864     1.024165        1.331369            0.0
# min            1.000000     1.000000        0.000000            1.0
# 25%            2.000000     2.000000        1.000000            1.0
# 50%            7.000000     3.000000        2.000000            1.0
# 75%           14.000000     4.000000        3.000000            1.0
# max           29.000000     5.000000        5.000000            1.0
#
#        EmployeeNumber  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean      1024.865306  ...                  2.712245           80.0
# std        602.024335  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%        491.250000  ...                  2.000000           80.0
# 50%       1020.500000  ...                  3.000000           80.0
# 75%       1555.750000  ...                  4.000000           80.0
# max       2068.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 35 columns]

# %%
df.dtypes
# Out:
# Age                         int64
# Attrition                   int64
# BusinessTravel              int64
# DailyRate                   int64
# Department                  int64
# DistanceFromHome            int64
# Education                   int64
# EducationField              int64
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int64
# JobSatisfaction             int64
# MaritalStatus               int64
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int64
# OverTime                    int64
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# dtype: object

# %%
Y_JS = df.JobSatisfaction
Y_ES = df.EnvironmentSatisfaction
Y_A = df.Attrition
X = df

# %%
u_JS, c_JS = np.unique(Y_JS, return_counts=True)
u_ES, c_ES = np.unique(Y_ES, return_counts=True)
u_A, c_A = np.unique(Y_A, return_counts=True)

plt.figure(figsize=(12, 5))
plt.subplot(1, 3, 1)
plt.bar(u_JS, c_JS)
plt.title('Job Satisfaction')
for i in range(len(u_JS)):
    plt.text(x = u_JS[i] , y = c_JS[i]+0.5, s = c_JS[i], size = 10)

plt.subplot(1, 3, 2)
plt.bar(u_ES, c_ES)
plt.title('Environment Satisfaction')
for i in range(len(u_ES)):
    plt.text(x = u_ES[i] , y = c_ES[i]+0.5, s = c_ES[i], size = 10)

plt.subplot(1, 3, 3)
plt.bar(u_A, c_A)
plt.title('Attrition')
for i in range(len(u_A)):
    plt.text(x = u_A[i] , y = c_A[i]+0.5, s = c_A[i], size = 10)

plt.show()

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_smote_JS, Y_smote_JS = smote.fit_resample(X, Y_JS)

u_smote, c_smote = np.unique(Y_smote_JS, return_counts=True)
plt.bar(u_smote, c_smote)
plt.title('Job Satisfaction')
for i in range(len(u_smote)):
    plt.text(x = u_smote[i] , y = c_smote[i]+0.5, s = c_smote[i], size = 10)

plt.show()

# %%
Y_smote_JS.shape
# Out:
# (1836,)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_smote_ES, Y_smote_ES = smote.fit_resample(X, Y_ES)

u_smote, c_smote = np.unique(Y_smote_ES, return_counts=True)
plt.bar(u_smote, c_smote)
plt.title('Environment Satisfaction')
for i in range(len(u_smote)):
    plt.text(x = u_smote[i] , y = c_smote[i]+0.5, s = c_smote[i], size = 10)

plt.show()

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_smote_A, Y_smote_A = smote.fit_resample(X, Y_A)

u_smote, c_smote = np.unique(Y_smote_A, return_counts=True)
plt.bar(u_smote, c_smote)
plt.title('Attrition')
for i in range(len(u_smote)):
    plt.text(x = u_smote[i] , y = c_smote[i]+0.5, s = c_smote[i], size = 10)

plt.show()

# %%
X_smote_JS.shape
# Out:
# (1836, 35)

# %%
#write correlation matrix for all the features with Job Satisfaction, Environment Satisfaction and Attrition
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /Users/subodhgujar/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/io/formats/style.py:3926: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Users/subodhgujar/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/io/formats/style.py:3927: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_644b7_row0_col0, #T_644b7_row1_col1, #T_644b7_row2_col2, #T_644b7_row3_col3, #T_644b7_row4_col4, #T_644b7_row5_col5, #T_644b7_row6_col6, #T_644b7_row7_col7, #T_644b7_row9_col9, #T_644b7_row10_col10, #T_644b7_row11_col11, #T_644b7_row12_col12, #T_644b7_row13_col13, #T_644b7_row14_col14, #T_644b7_row15_col15, #T_644b7_row16_col16, #T_644b7_row17_col17, #T_644b7_row18_col18, #T_644b7_row19_col19, #T_644b7_row20_col20, #T_644b7_row22_col22, #T_644b7_row23_col23, #T_644b7_row24_col24, #T_644b7_row25_col25, #T_644b7_row27_col27, #T_644b7_row28_col28, #T_644b7_row29_col29, #T_644b7_row30_col30, #T_644b7_row31_col31, #T_644b7_row32_col32, #T_644b7_row33_col33, #T_644b7_row34_col34 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_644b7_row0_col1, #T_644b7_row0_col4, #T_644b7_row0_col11, #T_644b7_row1_col6, #T_644b7_row2_col23, #T_644b7_row3_col19, #T_644b7_row5_col2, #T_644b7_row9_col24, #T_644b7_row10_col23, #T_644b7_row14_col24, #T_644b7_row16_col7, #T_644b7_row18_col1, #T_644b7_row20_col33, #T_644b7_row24_col2, #T_644b7_row29_col11, #T_644b7_row30_col5, #T_644b7_row32_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_644b7_row0_col2, #T_644b7_row1_col12, #T_644b7_row2_col3, #T_644b7_row3_col23, #T_644b7_row5_col3, #T_644b7_row7_col25, #T_644b7_row10_col33, #T_644b7_row12_col2, #T_644b7_row13_col9, #T_644b7_row13_col11, #T_644b7_row13_col29, #T_644b7_row16_col4, #T_644b7_row19_col5, #T_644b7_row19_col25, #T_644b7_row20_col32, #T_644b7_row22_col5, #T_644b7_row22_col12, #T_644b7_row22_col19, #T_644b7_row24_col5, #T_644b7_row24_col29, #T_644b7_row24_col33, #T_644b7_row28_col30, #T_644b7_row29_col12, #T_644b7_row30_col12, #T_644b7_row31_col4, #T_644b7_row31_col22, #T_644b7_row33_col22 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_644b7_row0_col3, #T_644b7_row3_col29, #T_644b7_row4_col10, #T_644b7_row5_col23, #T_644b7_row7_col22, #T_644b7_row10_col19, #T_644b7_row13_col16, #T_644b7_row14_col19, #T_644b7_row15_col10, #T_644b7_row15_col29, #T_644b7_row16_col11, #T_644b7_row19_col9, #T_644b7_row19_col29, #T_644b7_row20_col15, #T_644b7_row23_col5, #T_644b7_row24_col22, #T_644b7_row25_col29, #T_644b7_row25_col33, #T_644b7_row28_col16, #T_644b7_row29_col4, #T_644b7_row29_col10, #T_644b7_row30_col9, #T_644b7_row30_col16, #T_644b7_row31_col29, #T_644b7_row32_col3, #T_644b7_row33_col16 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_644b7_row0_col5, #T_644b7_row0_col24, #T_644b7_row1_col2, #T_644b7_row1_col24, #T_644b7_row2_col25, #T_644b7_row3_col11, #T_644b7_row4_col23, #T_644b7_row5_col30, #T_644b7_row11_col5, #T_644b7_row11_col22, #T_644b7_row13_col1, #T_644b7_row15_col0, #T_644b7_row15_col5, #T_644b7_row16_col5, #T_644b7_row16_col24, #T_644b7_row19_col3, #T_644b7_row19_col23, #T_644b7_row20_col7, #T_644b7_row22_col23, #T_644b7_row22_col24, #T_644b7_row22_col30, #T_644b7_row22_col33, #T_644b7_row23_col4, #T_644b7_row23_col7, #T_644b7_row23_col19, #T_644b7_row24_col11, #T_644b7_row27_col24, #T_644b7_row29_col23, #T_644b7_row30_col24, #T_644b7_row31_col1, #T_644b7_row31_col3, #T_644b7_row31_col24, #T_644b7_row32_col7, #T_644b7_row33_col3, #T_644b7_row34_col22 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_644b7_row0_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_644b7_row0_col7, #T_644b7_row1_col0, #T_644b7_row1_col10, #T_644b7_row1_col13, #T_644b7_row1_col14, #T_644b7_row1_col16, #T_644b7_row1_col18, #T_644b7_row1_col28, #T_644b7_row1_col30, #T_644b7_row1_col31, #T_644b7_row1_col32, #T_644b7_row1_col34, #T_644b7_row7_col6, #T_644b7_row9_col25, #T_644b7_row10_col24, #T_644b7_row11_col2, #T_644b7_row11_col4, #T_644b7_row11_col19, #T_644b7_row13_col24, #T_644b7_row14_col1, #T_644b7_row14_col7, #T_644b7_row15_col33, #T_644b7_row16_col2, #T_644b7_row16_col12, #T_644b7_row17_col3, #T_644b7_row17_col11, #T_644b7_row17_col27, #T_644b7_row18_col7, #T_644b7_row22_col29, #T_644b7_row25_col2, #T_644b7_row25_col9, #T_644b7_row25_col23, #T_644b7_row25_col24, #T_644b7_row27_col17, #T_644b7_row28_col1, #T_644b7_row28_col11, #T_644b7_row28_col15, #T_644b7_row29_col5, #T_644b7_row29_col22, #T_644b7_row31_col20, #T_644b7_row33_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_644b7_row0_col8, #T_644b7_row0_col21, #T_644b7_row0_col26, #T_644b7_row1_col8, #T_644b7_row1_col21, #T_644b7_row1_col26, #T_644b7_row2_col8, #T_644b7_row2_col21, #T_644b7_row2_col26, #T_644b7_row3_col8, #T_644b7_row3_col21, #T_644b7_row3_col26, #T_644b7_row4_col8, #T_644b7_row4_col21, #T_644b7_row4_col26, #T_644b7_row5_col8, #T_644b7_row5_col21, #T_644b7_row5_col26, #T_644b7_row6_col8, #T_644b7_row6_col21, #T_644b7_row6_col26, #T_644b7_row7_col8, #T_644b7_row7_col21, #T_644b7_row7_col26, #T_644b7_row8_col0, #T_644b7_row8_col1, #T_644b7_row8_col2, #T_644b7_row8_col3, #T_644b7_row8_col4, #T_644b7_row8_col5, #T_644b7_row8_col6, #T_644b7_row8_col7, #T_644b7_row8_col8, #T_644b7_row8_col9, #T_644b7_row8_col10, #T_644b7_row8_col11, #T_644b7_row8_col12, #T_644b7_row8_col13, #T_644b7_row8_col14, #T_644b7_row8_col15, #T_644b7_row8_col16, #T_644b7_row8_col17, #T_644b7_row8_col18, #T_644b7_row8_col19, #T_644b7_row8_col20, #T_644b7_row8_col21, #T_644b7_row8_col22, #T_644b7_row8_col23, #T_644b7_row8_col24, #T_644b7_row8_col25, #T_644b7_row8_col26, #T_644b7_row8_col27, #T_644b7_row8_col28, #T_644b7_row8_col29, #T_644b7_row8_col30, #T_644b7_row8_col31, #T_644b7_row8_col32, #T_644b7_row8_col33, #T_644b7_row8_col34, #T_644b7_row9_col8, #T_644b7_row9_col21, #T_644b7_row9_col26, #T_644b7_row10_col8, #T_644b7_row10_col21, #T_644b7_row10_col26, #T_644b7_row11_col8, #T_644b7_row11_col21, #T_644b7_row11_col26, #T_644b7_row12_col8, #T_644b7_row12_col21, #T_644b7_row12_col26, #T_644b7_row13_col8, #T_644b7_row13_col21, #T_644b7_row13_col26, #T_644b7_row14_col8, #T_644b7_row14_col21, #T_644b7_row14_col26, #T_644b7_row15_col8, #T_644b7_row15_col21, #T_644b7_row15_col26, #T_644b7_row16_col8, #T_644b7_row16_col21, #T_644b7_row16_col26, #T_644b7_row17_col8, #T_644b7_row17_col21, #T_644b7_row17_col26, #T_644b7_row18_col8, #T_644b7_row18_col21, #T_644b7_row18_col26, #T_644b7_row19_col8, #T_644b7_row19_col21, #T_644b7_row19_col26, #T_644b7_row20_col8, #T_644b7_row20_col21, #T_644b7_row20_col26, #T_644b7_row21_col0, #T_644b7_row21_col1, #T_644b7_row21_col2, #T_644b7_row21_col3, #T_644b7_row21_col4, #T_644b7_row21_col5, #T_644b7_row21_col6, #T_644b7_row21_col7, #T_644b7_row21_col8, #T_644b7_row21_col9, #T_644b7_row21_col10, #T_644b7_row21_col11, #T_644b7_row21_col12, #T_644b7_row21_col13, #T_644b7_row21_col14, #T_644b7_row21_col15, #T_644b7_row21_col16, #T_644b7_row21_col17, #T_644b7_row21_col18, #T_644b7_row21_col19, #T_644b7_row21_col20, #T_644b7_row21_col21, #T_644b7_row21_col22, #T_644b7_row21_col23, #T_644b7_row21_col24, #T_644b7_row21_col25, #T_644b7_row21_col26, #T_644b7_row21_col27, #T_644b7_row21_col28, #T_644b7_row21_col29, #T_644b7_row21_col30, #T_644b7_row21_col31, #T_644b7_row21_col32, #T_644b7_row21_col33, #T_644b7_row21_col34, #T_644b7_row22_col8, #T_644b7_row22_col21, #T_644b7_row22_col26, #T_644b7_row23_col8, #T_644b7_row23_col21, #T_644b7_row23_col26, #T_644b7_row24_col8, #T_644b7_row24_col21, #T_644b7_row24_col26, #T_644b7_row25_col8, #T_644b7_row25_col21, #T_644b7_row25_col26, #T_644b7_row26_col0, #T_644b7_row26_col1, #T_644b7_row26_col2, #T_644b7_row26_col3, #T_644b7_row26_col4, #T_644b7_row26_col5, #T_644b7_row26_col6, #T_644b7_row26_col7, #T_644b7_row26_col8, #T_644b7_row26_col9, #T_644b7_row26_col10, #T_644b7_row26_col11, #T_644b7_row26_col12, #T_644b7_row26_col13, #T_644b7_row26_col14, #T_644b7_row26_col15, #T_644b7_row26_col16, #T_644b7_row26_col17, #T_644b7_row26_col18, #T_644b7_row26_col19, #T_644b7_row26_col20, #T_644b7_row26_col21, #T_644b7_row26_col22, #T_644b7_row26_col23, #T_644b7_row26_col24, #T_644b7_row26_col25, #T_644b7_row26_col26, #T_644b7_row26_col27, #T_644b7_row26_col28, #T_644b7_row26_col29, #T_644b7_row26_col30, #T_644b7_row26_col31, #T_644b7_row26_col32, #T_644b7_row26_col33, #T_644b7_row26_col34, #T_644b7_row27_col8, #T_64

# %%
df_temp = df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis=1)

# %%
corr_JS = df_temp.drop(['EnvironmentSatisfaction', 'Attrition'], axis=1).corrwith(df.JobSatisfaction)
corr_JS
# Out:
# Age                        -0.004892
# BusinessTravel             -0.033962
# DailyRate                   0.030571
# Department                  0.021001
# DistanceFromHome           -0.003669
# Education                  -0.011296
# EducationField             -0.034401
# Gender                      0.033252
# HourlyRate                 -0.071335
# JobInvolvement             -0.021476
# JobLevel                   -0.001944
# JobRole                     0.017537
# JobSatisfaction             1.000000
# MaritalStatus               0.024360
# MonthlyIncome              -0.007157
# MonthlyRate                 0.000644
# NumCompaniesWorked         -0.055699
# OverTime                    0.024539
# PercentSalaryHike           0.020002
# PerformanceRating           0.002297
# RelationshipSatisfaction   -0.012454
# StockOptionLevel            0.010690
# TotalWorkingYears          -0.020185
# TrainingTimesLastYear      -0.005779
# WorkLifeBalance            -0.019459
# YearsAtCompany             -0.003803
# YearsInCurrentRole         -0.002305
# YearsSinceLastPromotion    -0.018214
# YearsWithCurrManager       -0.027656
# dtype: float64

# %%
corr_ES = df_temp.drop(['JobSatisfaction', 'Attrition'], axis=1).corrwith(df.EnvironmentSatisfaction)
corr_ES
# Out:
# Age                         0.010146
# BusinessTravel              0.004174
# DailyRate                   0.018355
# Department                 -0.019395
# DistanceFromHome           -0.016075
# Education                  -0.027128
# EducationField              0.043163
# EnvironmentSatisfaction     1.000000
# Gender                      0.000508
# HourlyRate                 -0.049857
# JobInvolvement             -0.008278
# JobLevel                    0.001212
# JobRole                    -0.017321
# MaritalStatus              -0.003593
# MonthlyIncome              -0.006259
# MonthlyRate                 0.037600
# NumCompaniesWorked          0.012594
# OverTime                    0.070132
# PercentSalaryHike          -0.031701
# PerformanceRating          -0.029548
# RelationshipSatisfaction    0.007665
# StockOptionLevel            0.003432
# TotalWorkingYears          -0.002693
# TrainingTimesLastYear      -0.019359
# WorkLifeBalance             0.027627
# YearsAtCompany              0.001458
# YearsInCurrentRole          0.018007
# YearsSinceLastPromotion     0.016194
# YearsWithCurrManager       -0.004999
# dtype: float64

# %%
corr_A = df_temp.drop(['JobSatisfaction', 'EnvironmentSatisfaction'], axis=1).corrwith(df.Attrition)
corr_A
# Out:
# Age                        -0.159205
# Attrition                   1.000000
# BusinessTravel              0.000074
# DailyRate                  -0.056652
# Department                  0.063991
# DistanceFromHome            0.077924
# Education                  -0.031373
# EducationField              0.026846
# Gender                      0.029453
# HourlyRate                 -0.006846
# JobInvolvement             -0.130016
# JobLevel                   -0.169105
# JobRole                     0.067151
# MaritalStatus               0.162070
# MonthlyIncome              -0.159840
# MonthlyRate                 0.015170
# NumCompaniesWorked          0.043494
# OverTime                    0.246118
# PercentSalaryHike          -0.013478
# PerformanceRating           0.002889
# RelationshipSatisfaction   -0.045872
# StockOptionLevel           -0.137145
# TotalWorkingYears          -0.171063
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# YearsAtCompany             -0.134392
# YearsInCurrentRole         -0.160545
# YearsSinceLastPromotion    -0.033019
# YearsWithCurrManager       -0.156199
# dtype: float64

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

sel = SelectFromModel(Lasso(alpha=0.005, random_state=42))
X_JS = X_smote_JS.drop(['Attrition','EnvironmentSatisfaction','JobSatisfaction'], axis=1)
sel.fit(X_JS, Y_smote_JS)
print("Job Statisfaction", sel.get_support())
print("Selected Features", X_JS.columns[sel.get_support()])
X_JS = X_JS[X_JS.columns[sel.get_support()]]

sel = SelectFromModel(Lasso(alpha=0.005, random_state=42))
X_ES = X_smote_ES.drop(['Attrition','EnvironmentSatisfaction','JobSatisfaction'], axis=1)
sel.fit(X_ES, Y_smote_ES)
print("\n\nEmployee Statisfaction", sel.get_support())
print("Selected Features", X_ES.columns[sel.get_support()])
X_ES = X_ES[X_ES.columns[sel.get_support()]]


sel = SelectFromModel(Lasso(alpha=0.005, random_state=42))
X_A = X_smote_A.drop(['Attrition'], axis=1)
sel.fit(X_A, Y_smote_A)
print("\n\nAttrition", sel.get_support())
print("Selected Features", X_A.columns[sel.get_support()])
X_A = X_A[X_A.columns[sel.get_support()]]
# Out:
# Job Statisfaction [ True  True  True  True False  True False False  True  True  True  True
#   True  True  True  True False  True False  True  True  True  True False
#   True  True  True  True  True  True  True  True]
# Selected Features Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'Education',
#        'EmployeeNumber', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
#
#
# Employee Statisfaction [ True  True  True  True  True  True  True False  True  True  True  True
#   True  True  True  True False  True False  True  True  True  True False
#   True  True  True  True  True  True  True  True]
# Selected Features Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeNumber', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus',
#        'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
#
#
# Attrition [ True  True  True  True  True  True False False False  True  True  True
#   True  True  True  True  True False False  True False  True  True  True
#   True False  True  True  True  True  True  True  True  True]
# Selected Features Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
print(X_JS.shape)
print(Y_smote_JS.shape)
# Out:
# (1836, 28)
# (1836,)

# %%
# Out:
# array([[  5118.17100011,   -654.94824135],
#        [ 10521.7322841 ,  -1669.78427038],
#        [-12067.33800996,  -4080.70766683],
#        ...,
#        [   616.52235744,  -1917.05948034],
#        [ -5666.28701509,   4070.17993894],
#        [  8353.05314759,   3290.95154344]])

# %%
# Out:
# array([[  5010.14542179,   -759.83325799],
#        [ 10403.14267977,  -1825.88806633],
#        [-12206.9784063 ,  -4022.0060117 ],
#        ...,
#        [  1966.85079615,  -4150.92106107],
#        [  9123.06517671,   3432.81189988],
#        [  6905.63399964,    565.02538568]])

# %%
# Out:
# array([[  5137.55951205,     65.56875206],
#        [ 10527.86551858,  -1027.26964046],
#        [-12095.0807792 ,  -3116.63850194],
#        ...,
#        [  7384.99160841,  -2807.69888531],
#        [-11334.69126427,  -3033.306297  ],
#        [  5289.63173639,  -3671.68967919]])

# %%
from sklearn.model_selection import train_test_split
X_JS_train, X_JS_test, Y_JS_train, Y_JS_test = train_test_split(X_JS, Y_smote_JS, test_size=0.2, random_state=42)
X_ES_train, X_ES_test, Y_ES_train, Y_ES_test = train_test_split(X_ES, Y_smote_ES, test_size=0.2, random_state=42)
X_A_train, X_A_test, Y_A_train, Y_A_test = train_test_split(X_A, Y_smote_A, test_size=0.2, random_state=42)

# %%
X_JS_train.to_csv('Dataset/X_JS_train.csv', index=False)
X_JS_test.to_csv('Dataset/X_JS_test.csv', index=False)
Y_JS_train.to_csv('Dataset/Y_JS_train.csv', index=False)
Y_JS_test.to_csv('Dataset/Y_JS_test.csv', index=False)

X_ES_train.to_csv('Dataset/X_ES_train.csv', index=False)
X_ES_test.to_csv('Dataset/X_ES_test.csv', index=False)
Y_ES_train.to_csv('Dataset/Y_ES_train.csv', index=False)
Y_ES_test.to_csv('Dataset/Y_ES_test.csv', index=False)


X_A_train.to_csv('Dataset/X_A_train.csv', index=False)
X_A_test.to_csv('Dataset/X_A_test.csv', index=False)
Y_A_train.to_csv('Dataset/Y_A_train.csv', index=False)
Y_A_test.to_csv('Dataset/Y_A_test.csv', index=False)

# %%
#write a function to create a model for each of the three target variables using pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

def create_model(model, X_train, Y_train, X_test, Y_test, Y_name, name):
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    print("\n\n\n" + Y_name + " " + name + " Model")
    print("Accuracy: ", accuracy_score(Y_test, Y_pred))
    print("Precision: ", precision_score(Y_test, Y_pred, average='macro'))
    print("Recall: ", recall_score(Y_test, Y_pred, average='macro'))
    print("F1 Score: ", f1_score(Y_test, Y_pred, average='macro'))
    print("Confusion Matrix: \n", confusion_matrix(Y_test, Y_pred))
    print("Classification Report: \n", classification_report(Y_test, Y_pred))

# %%
def get_models(model, name):    
    #Job Satisfaction
    model_JS = Pipeline([('scaler', StandardScaler()), ('model', model)])
    create_model(model_JS, X_JS_train, Y_JS_train, X_JS_test, Y_JS_test, "JS", name)

    #Environment Satisfaction
    model_ES = Pipeline([('scaler', StandardScaler()), ('model', model)])
    create_model(model_ES, X_ES_train, Y_ES_train, X_ES_test, Y_ES_test, "ES", name)

    #Attrition
    model_A = Pipeline([('scaler', StandardScaler()), ('model', model)])
    create_model(model_A, X_A_train, Y_A_train, X_A_test, Y_A_test, "A", name)

    return model_JS, model_ES, model_A

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
model_JS_RF, model_ES_RF, model_A_RF = get_models(RandomForestClassifier(n_estimators=200, random_state=42), "Random Forest")
# Out:
# JS Random Forest Model
# Accuracy:  0.41304347826086957
# Precision:  0.41168204275055453
# Recall:  0.413093607171778
# F1 Score:  0.41220683665285873
# Confusion Matrix:
#  [[40 12 20 15]
#  [ 9 52 21 13]
#  [21 12 30 29]
#  [20 20 24 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.44      0.46      0.45        87
#            1       0.54      0.55      0.54        95
#            2       0.32      0.33      0.32        92
#            3       0.34      0.32      0.33        94
#
#     accuracy                           0.41       368
#    macro avg       0.41      0.41      0.41       368
# weighted avg       0.41      0.41      0.41       368
#
#
#
#
# ES Random Forest Model
# Accuracy:  0.44077134986225897
# Precision:  0.43129426493270884
# Recall:  0.44876878368502787
# F1 Score:  0.434443756101224
# Confusion Matrix:
#  [[57  6  6 13]
#  [19 48 18 11]
#  [23 10 33 23]
#  [12 24 38 22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.70      0.59        82
#            1       0.55      0.50      0.52        96
#            2       0.35      0.37      0.36        89
#            3       0.32      0.23      0.27        96
#
#     accuracy                           0.44       363
#    macro avg       0.43      0.45      0.43       363
# weighted avg       0.43      0.44      0.43       363
#
#
#
#
# A Random Forest Model
# Accuracy:  0.9109311740890689
# Precision:  0.9117521367521368
# Recall:  0.910672131147541
# F1 Score:  0.9108376404955287
# Confusion Matrix:
#  [[233  17]
#  [ 27 217]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91       250
#            1       0.93      0.89      0.91       244
#
#     accuracy                           0.91       494
#    macro avg       0.91      0.91      0.91       494
# weighted avg       0.91      0.91      0.91       494

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
model_JS_LR, model_ES_LR, model_A_LR = get_models(LogisticRegression(random_state=42), "Logistic Regression")
# Out:
# JS Logistic Regression Model
# Accuracy:  0.3070652173913043
# Precision:  0.30818123587405505
# Recall:  0.30722751026502426
# F1 Score:  0.3076524092481539
# Confusion Matrix:
#  [[29 27 18 13]
#  [22 30 26 17]
#  [21 18 23 30]
#  [15 19 29 31]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.33      0.33      0.33        87
#            1       0.32      0.32      0.32        95
#            2       0.24      0.25      0.24        92
#            3       0.34      0.33      0.34        94
#
#     accuracy                           0.31       368
#    macro avg       0.31      0.31      0.31       368
# weighted avg       0.31      0.31      0.31       368
#
#
#
#
# ES Logistic Regression Model
# Accuracy:  0.3305785123966942
# Precision:  0.3307638888888889
# Recall:  0.3350304307116105
# F1 Score:  0.3269678720920873
# Confusion Matrix:
#  [[41 14 14 13]
#  [39 28 12 17]
#  [18 14 21 36]
#  [22 16 28 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.34      0.50      0.41        82
#            1       0.39      0.29      0.33        96
#            2       0.28      0.24      0.26        89
#            3       0.31      0.31      0.31        96
#
#     accuracy                           0.33       363
#    macro avg       0.33      0.34      0.33       363
# weighted avg       0.33      0.33      0.33       363
#
#
#
#
# A Logistic Regression Model
# Accuracy:  0.8299595141700404
# Precision:  0.8299895095725152
# Recall:  0.830032786885246
# F1 Score:  0.8299567269866248
# Confusion Matrix:
#  [[206  44]
#  [ 40 204]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       250
#            1       0.82      0.84      0.83       244
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494

# %%
#AdaBoost Classifier
from sklearn.ensemble import AdaBoostClassifier
model_JS_AB, model_ES_AB, model_A_AB = get_models(AdaBoostClassifier(n_estimators=200, random_state=42), "AdaBoost")
# Out:
# JS AdaBoost Model
# Accuracy:  0.33695652173913043
# Precision:  0.33240225459297046
# Recall:  0.33869855385856906
# F1 Score:  0.33397210044156345
# Confusion Matrix:
#  [[40 19 17 11]
#  [21 37 16 21]
#  [24 18 24 26]
#  [22 21 28 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.37      0.46      0.41        87
#            1       0.39      0.39      0.39        95
#            2       0.28      0.26      0.27        92
#            3       0.28      0.24      0.26        94
#
#     accuracy                           0.34       368
#    macro avg       0.33      0.34      0.33       368
# weighted avg       0.33      0.34      0.33       368
#
#
#
#
# ES AdaBoost Model
# Accuracy:  0.3443526170798898
# Precision:  0.34280508828154727
# Recall:  0.3494500491002101
# F1 Score:  0.34265159838104475
# Confusion Matrix:
#  [[40 15 15 12]
#  [32 30 20 14]
#  [18 17 30 24]
#  [19 25 27 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.37      0.49      0.42        82
#            1       0.34      0.31      0.33        96
#            2       0.33      0.34      0.33        89
#            3       0.33      0.26      0.29        96
#
#     accuracy                           0.34       363
#    macro avg       0.34      0.35      0.34       363
# weighted avg       0.34      0.34      0.34       363
#
#
#
#
# A AdaBoost Model
# Accuracy:  0.8603238866396761
# Precision:  0.860389024650255
# Recall:  0.8602295081967213
# F1 Score:  0.8602775101965526
# Confusion Matrix:
#  [[217  33]
#  [ 36 208]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86       250
#            1       0.86      0.85      0.86       244
#
#     accuracy                           0.86       494
#    macro avg       0.86      0.86      0.86       494
# weighted avg       0.86      0.86      0.86       494

# %%
#KNN Classifier
from sklearn.neighbors import KNeighborsClassifier
model_JS_KNN, model_ES_KNN, model_A_KNN = get_models(KNeighborsClassifier(n_neighbors=5), "KNN")
# Out:
# JS KNN Model
# Accuracy:  0.33695652173913043
# Precision:  0.31824731461954553
# Recall:  0.33902965930248763
# F1 Score:  0.3133372734436564
# Confusion Matrix:
#  [[45 18 15  9]
#  [22 51 15  7]
#  [37 22 18 15]
#  [44 18 22 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.30      0.52      0.38        87
#            1       0.47      0.54      0.50        95
#            2       0.26      0.20      0.22        92
#            3       0.24      0.11      0.15        94
#
#     accuracy                           0.34       368
#    macro avg       0.32      0.34      0.31       368
# weighted avg       0.32      0.34      0.31       368
#
#
#
#
# ES KNN Model
# Accuracy:  0.36363636363636365
# Precision:  0.3540794016110471
# Recall:  0.3706266557047593
# F1 Score:  0.3401018855030597
# Confusion Matrix:
#  [[54 10  7 11]
#  [34 46  8  8]
#  [40 22 14 13]
#  [30 22 26 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.34      0.66      0.45        82
#            1       0.46      0.48      0.47        96
#            2       0.25      0.16      0.19        89
#            3       0.36      0.19      0.25        96
#
#     accuracy                           0.36       363
#    macro avg       0.35      0.37      0.34       363
# weighted avg       0.36      0.36      0.34       363
#
#
#
#
# A KNN Model
# Accuracy:  0.8522267206477733
# Precision:  0.8713011894720535
# Recall:  0.8536065573770492
# F1 Score:  0.8506347464120778
# Confusion Matrix:
#  [[185  65]
#  [  8 236]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.74      0.84       250
#            1       0.78      0.97      0.87       244
#
#     accuracy                           0.85       494
#    macro avg       0.87      0.85      0.85       494
# weighted avg       0.87      0.85      0.85       494

# %%
#SVM Classifier
from sklearn.svm import SVC
model_JS_SVM, model_ES_SVM, model_A_SVM = get_models(SVC(random_state=42), "SVM")
# Out:
# JS SVM Model
# Accuracy:  0.36141304347826086
# Precision:  0.37024253943030544
# Recall:  0.3613717217539047
# F1 Score:  0.36459920811496316
# Confusion Matrix:
#  [[33 13 22 19]
#  [14 41 24 16]
#  [19 14 30 29]
#  [16 15 34 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.38      0.39        87
#            1       0.49      0.43      0.46        95
#            2       0.27      0.33      0.30        92
#            3       0.31      0.31      0.31        94
#
#     accuracy                           0.36       368
#    macro avg       0.37      0.36      0.36       368
# weighted avg       0.37      0.36      0.36       368
#
#
#
#
# ES SVM Model
# Accuracy:  0.35537190082644626
# Precision:  0.36131301835802815
# Recall:  0.3602763599616333
# F1 Score:  0.3580541839826755
# Confusion Matrix:
#  [[40  8 16 18]
#  [30 33 16 17]
#  [12  8 32 37]
#  [14 24 34 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.42      0.49      0.45        82
#            1       0.45      0.34      0.39        96
#            2       0.33      0.36      0.34        89
#            3       0.25      0.25      0.25        96
#
#     accuracy                           0.36       363
#    macro avg       0.36      0.36      0.36       363
# weighted avg       0.36      0.36      0.35       363
#
#
#
#
# A SVM Model
# Accuracy:  0.8866396761133604
# Precision:  0.8869321165966386
# Recall:  0.8864754098360657
# F1 Score:  0.8865727453134995
# Confusion Matrix:
#  [[225  25]
#  [ 31 213]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       250
#            1       0.89      0.87      0.88       244
#
#     accuracy                           0.89       494
#    macro avg       0.89      0.89      0.89       494
# weighted avg       0.89      0.89      0.89       494

# %%
#naive bayes classifier
from sklearn.naive_bayes import GaussianNB
model_JS_NB, model_ES_NB, model_A_NB = get_models(GaussianNB(), "Naive Bayes")
# Out:
# JS Naive Bayes Model
# Accuracy:  0.3125
# Precision:  0.3004505460468958
# Recall:  0.3087632905271888
# F1 Score:  0.2962155632919231
# Confusion Matrix:
#  [[15 40 21 11]
#  [ 9 54 22 10]
#  [15 28 21 28]
#  [18 22 29 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.26      0.17      0.21        87
#            1       0.38      0.57      0.45        95
#            2       0.23      0.23      0.23        92
#            3       0.34      0.27      0.30        94
#
#     accuracy                           0.31       368
#    macro avg       0.30      0.31      0.30       368
# weighted avg       0.30      0.31      0.30       368
#
#
#
#
# ES Naive Bayes Model
# Accuracy:  0.3002754820936639
# Precision:  0.29860559503901896
# Recall:  0.3055303393623824
# F1 Score:  0.29356779876044187
# Confusion Matrix:
#  [[40 20 13  9]
#  [43 30  8 15]
#  [22 23 19 25]
#  [25 27 24 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.31      0.49      0.38        82
#            1       0.30      0.31      0.31        96
#            2       0.30      0.21      0.25        89
#            3       0.29      0.21      0.24        96
#
#     accuracy                           0.30       363
#    macro avg       0.30      0.31      0.29       363
# weighted avg       0.30      0.30      0.29       363
#
#
#
#
# A Naive Bayes Model
# Accuracy:  0.7368421052631579
# Precision:  0.7414068745003997
# Recall:  0.737639344262295
# F1 Score:  0.7359939486622926
# Confusion Matrix:
#  [[168  82]
#  [ 48 196]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72       250
#            1       0.71      0.80      0.75       244
#
#     accuracy                           0.74       494
#    macro avg       0.74      0.74      0.74       494
# weighted avg       0.74      0.74      0.74       494

# %%
#MLP Classifier
from sklearn.neural_network import MLPClassifier
model_JS_MLP, model_ES_MLP, model_A_MLP = get_models(MLPClassifier(hidden_layer_sizes=[10, 15, 15, 10] ,random_state=42), "MLP")
# Out:
# /Users/subodhgujar/.pyenv/versions/3.8.10/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# JS MLP Model
# Accuracy:  0.32608695652173914
# Precision:  0.32751663165266104
# Recall:  0.325634194380973
# F1 Score:  0.3252133573662991
# Confusion Matrix:
#  [[28 25 18 16]
#  [23 34 16 22]
#  [15 27 25 25]
#  [19 26 16 33]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.33      0.32      0.33        87
#            1       0.30      0.36      0.33        95
#            2       0.33      0.27      0.30        92
#            3       0.34      0.35      0.35        94
#
#     accuracy                           0.33       368
#    macro avg       0.33      0.33      0.33       368
# weighted avg       0.33      0.33      0.33       368
# /Users/subodhgujar/.pyenv/versions/3.8.10/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ES MLP Model
# Accuracy:  0.3140495867768595
# Precision:  0.3132351860831284
# Recall:  0.3134855725312871
# F1 Score:  0.3123249395436274
# Confusion Matrix:
#  [[24 21 17 20]
#  [19 36 26 15]
#  [19 21 29 20]
#  [17 25 29 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.30      0.29      0.30        82
#            1       0.35      0.38      0.36        96
#            2       0.29      0.33      0.31        89
#            3       0.31      0.26      0.28        96
#
#     accuracy                           0.31       363
#    macro avg       0.31      0.31      0.31       363
# weighted avg       0.31      0.31      0.31       363
#
#
#
#
# A MLP Model
# Accuracy:  0.8238866396761133
# Precision:  0.8240699752430607
# Recall:  0.824032786885246
# F1 Score:  0.8238859180035651
# Confusion Matrix:
#  [[203  47]
#  [ 40 204]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82       250
#            1       0.81      0.84      0.82       244
#
#     accuracy                           0.82       494
#    macro avg       0.82      0.82      0.82       494
# weighted avg       0.82      0.82      0.82       494
# /Users/subodhgujar/.pyenv/versions/3.8.10/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
