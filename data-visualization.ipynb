# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Dataset/data.csv')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['BusinessTravel'] = le.fit_transform(df['BusinessTravel'])
df['Department'] = le.fit_transform(df['Department'])
df['EducationField'] = le.fit_transform(df['EducationField'])
df['Attrition'] = le.fit_transform(df['Attrition'])
df['Gender'] = le.fit_transform(df['Gender'])
df['JobRole'] = le.fit_transform(df['JobRole'])
df['MaritalStatus'] = le.fit_transform(df['MaritalStatus'])
df['OverTime'] = le.fit_transform(df['OverTime'])
df['Over18'] = le.fit_transform(df['Over18'])
df['JobSatisfaction'] = le.fit_transform(df['JobSatisfaction'])
df['EnvironmentSatisfaction'] = le.fit_transform(df['EnvironmentSatisfaction'])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 35 columns]

# %%
#check for Nan values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.106864     1.024165        1.331369            0.0
# min            1.000000     1.000000        0.000000            1.0
# 25%            2.000000     2.000000        1.000000            1.0
# 50%            7.000000     3.000000        2.000000            1.0
# 75%           14.000000     4.000000        3.000000            1.0
# max           29.000000     5.000000        5.000000            1.0
#
#        EmployeeNumber  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean      1024.865306  ...                  2.712245           80.0
# std        602.024335  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%        491.250000  ...                  2.000000           80.0
# 50%       1020.500000  ...                  3.000000           80.0
# 75%       1555.750000  ...                  4.000000           80.0
# max       2068.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 35 columns]

# %%
df.dtypes
# Out:
# Age                         int64
# Attrition                   int64
# BusinessTravel              int64
# DailyRate                   int64
# Department                  int64
# DistanceFromHome            int64
# Education                   int64
# EducationField              int64
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int64
# JobSatisfaction             int64
# MaritalStatus               int64
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int64
# OverTime                    int64
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# dtype: object

# %%
Y_JS = df.JobSatisfaction
Y_ES = df.EnvironmentSatisfaction
Y_A = df.Attrition
X = df.drop(['JobSatisfaction', 'EnvironmentSatisfaction', 'Attrition'], axis=1)

# %%
u_JS, c_JS = np.unique(Y_JS, return_counts=True)
u_ES, c_ES = np.unique(Y_ES, return_counts=True)
u_A, c_A = np.unique(Y_A, return_counts=True)

plt.figure(figsize=(12, 5))
plt.subplot(1, 3, 1)
plt.bar(u_JS, c_JS)
plt.title('Job Satisfaction')
for i in range(len(u_JS)):
    plt.text(x = u_JS[i] , y = c_JS[i]+0.5, s = c_JS[i], size = 10)

plt.subplot(1, 3, 2)
plt.bar(u_ES, c_ES)
plt.title('Environment Satisfaction')
for i in range(len(u_ES)):
    plt.text(x = u_ES[i] , y = c_ES[i]+0.5, s = c_ES[i], size = 10)

plt.subplot(1, 3, 3)
plt.bar(u_A, c_A)
plt.title('Attrition')
for i in range(len(u_A)):
    plt.text(x = u_A[i] , y = c_A[i]+0.5, s = c_A[i], size = 10)

plt.show()

# %%
#write correlation matrix for all the features with Job Satisfaction, Environment Satisfaction and Attrition
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /Users/subodhgujar/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/io/formats/style.py:3926: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Users/subodhgujar/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/io/formats/style.py:3927: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_8933b_row0_col0, #T_8933b_row1_col1, #T_8933b_row2_col2, #T_8933b_row3_col3, #T_8933b_row4_col4, #T_8933b_row5_col5, #T_8933b_row6_col6, #T_8933b_row7_col7, #T_8933b_row9_col9, #T_8933b_row10_col10, #T_8933b_row11_col11, #T_8933b_row12_col12, #T_8933b_row13_col13, #T_8933b_row14_col14, #T_8933b_row15_col15, #T_8933b_row16_col16, #T_8933b_row17_col17, #T_8933b_row18_col18, #T_8933b_row19_col19, #T_8933b_row20_col20, #T_8933b_row22_col22, #T_8933b_row23_col23, #T_8933b_row24_col24, #T_8933b_row25_col25, #T_8933b_row27_col27, #T_8933b_row28_col28, #T_8933b_row29_col29, #T_8933b_row30_col30, #T_8933b_row31_col31, #T_8933b_row32_col32, #T_8933b_row33_col33, #T_8933b_row34_col34 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8933b_row0_col1, #T_8933b_row0_col4, #T_8933b_row0_col11, #T_8933b_row1_col6, #T_8933b_row2_col23, #T_8933b_row3_col19, #T_8933b_row5_col2, #T_8933b_row9_col24, #T_8933b_row10_col23, #T_8933b_row14_col24, #T_8933b_row16_col7, #T_8933b_row18_col1, #T_8933b_row20_col33, #T_8933b_row24_col2, #T_8933b_row29_col11, #T_8933b_row30_col5, #T_8933b_row32_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_8933b_row0_col2, #T_8933b_row1_col12, #T_8933b_row2_col3, #T_8933b_row3_col23, #T_8933b_row5_col3, #T_8933b_row7_col25, #T_8933b_row10_col33, #T_8933b_row12_col2, #T_8933b_row13_col9, #T_8933b_row13_col11, #T_8933b_row13_col29, #T_8933b_row16_col4, #T_8933b_row19_col5, #T_8933b_row19_col25, #T_8933b_row20_col32, #T_8933b_row22_col5, #T_8933b_row22_col12, #T_8933b_row22_col19, #T_8933b_row24_col5, #T_8933b_row24_col29, #T_8933b_row24_col33, #T_8933b_row28_col30, #T_8933b_row29_col12, #T_8933b_row30_col12, #T_8933b_row31_col4, #T_8933b_row31_col22, #T_8933b_row33_col22 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_8933b_row0_col3, #T_8933b_row3_col29, #T_8933b_row4_col10, #T_8933b_row5_col23, #T_8933b_row7_col22, #T_8933b_row10_col19, #T_8933b_row13_col16, #T_8933b_row14_col19, #T_8933b_row15_col10, #T_8933b_row15_col29, #T_8933b_row16_col11, #T_8933b_row19_col9, #T_8933b_row19_col29, #T_8933b_row20_col15, #T_8933b_row23_col5, #T_8933b_row24_col22, #T_8933b_row25_col29, #T_8933b_row25_col33, #T_8933b_row28_col16, #T_8933b_row29_col4, #T_8933b_row29_col10, #T_8933b_row30_col9, #T_8933b_row30_col16, #T_8933b_row31_col29, #T_8933b_row32_col3, #T_8933b_row33_col16 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_8933b_row0_col5, #T_8933b_row0_col24, #T_8933b_row1_col2, #T_8933b_row1_col24, #T_8933b_row2_col25, #T_8933b_row3_col11, #T_8933b_row4_col23, #T_8933b_row5_col30, #T_8933b_row11_col5, #T_8933b_row11_col22, #T_8933b_row13_col1, #T_8933b_row15_col0, #T_8933b_row15_col5, #T_8933b_row16_col5, #T_8933b_row16_col24, #T_8933b_row19_col3, #T_8933b_row19_col23, #T_8933b_row20_col7, #T_8933b_row22_col23, #T_8933b_row22_col24, #T_8933b_row22_col30, #T_8933b_row22_col33, #T_8933b_row23_col4, #T_8933b_row23_col7, #T_8933b_row23_col19, #T_8933b_row24_col11, #T_8933b_row27_col24, #T_8933b_row29_col23, #T_8933b_row30_col24, #T_8933b_row31_col1, #T_8933b_row31_col3, #T_8933b_row31_col24, #T_8933b_row32_col7, #T_8933b_row33_col3, #T_8933b_row34_col22 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_8933b_row0_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_8933b_row0_col7, #T_8933b_row1_col0, #T_8933b_row1_col10, #T_8933b_row1_col13, #T_8933b_row1_col14, #T_8933b_row1_col16, #T_8933b_row1_col18, #T_8933b_row1_col28, #T_8933b_row1_col30, #T_8933b_row1_col31, #T_8933b_row1_col32, #T_8933b_row1_col34, #T_8933b_row7_col6, #T_8933b_row9_col25, #T_8933b_row10_col24, #T_8933b_row11_col2, #T_8933b_row11_col4, #T_8933b_row11_col19, #T_8933b_row13_col24, #T_8933b_row14_col1, #T_8933b_row14_col7, #T_8933b_row15_col33, #T_8933b_row16_col2, #T_8933b_row16_col12, #T_8933b_row17_col3, #T_8933b_row17_col11, #T_8933b_row17_col27, #T_8933b_row18_col7, #T_8933b_row22_col29, #T_8933b_row25_col2, #T_8933b_row25_col9, #T_8933b_row25_col23, #T_8933b_row25_col24, #T_8933b_row27_col17, #T_8933b_row28_col1, #T_8933b_row28_col11, #T_8933b_row28_col15, #T_8933b_row29_col5, #T_8933b_row29_col22, #T_8933b_row31_col20, #T_8933b_row33_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8933b_row0_col8, #T_8933b_row0_col21, #T_8933b_row0_col26, #T_8933b_row1_col8, #T_8933b_row1_col21, #T_8933b_row1_col26, #T_8933b_row2_col8, #T_8933b_row2_col21, #T_8933b_row2_col26, #T_8933b_row3_col8, #T_8933b_row3_col21, #T_8933b_row3_col26, #T_8933b_row4_col8, #T_8933b_row4_col21, #T_8933b_row4_col26, #T_8933b_row5_col8, #T_8933b_row5_col21, #T_8933b_row5_col26, #T_8933b_row6_col8, #T_8933b_row6_col21, #T_8933b_row6_col26, #T_8933b_row7_col8, #T_8933b_row7_col21, #T_8933b_row7_col26, #T_8933b_row8_col0, #T_8933b_row8_col1, #T_8933b_row8_col2, #T_8933b_row8_col3, #T_8933b_row8_col4, #T_8933b_row8_col5, #T_8933b_row8_col6, #T_8933b_row8_col7, #T_8933b_row8_col8, #T_8933b_row8_col9, #T_8933b_row8_col10, #T_8933b_row8_col11, #T_8933b_row8_col12, #T_8933b_row8_col13, #T_8933b_row8_col14, #T_8933b_row8_col15, #T_8933b_row8_col16, #T_8933b_row8_col17, #T_8933b_row8_col18, #T_8933b_row8_col19, #T_8933b_row8_col20, #T_8933b_row8_col21, #T_8933b_row8_col22, #T_8933b_row8_col23, #T_8933b_row8_col24, #T_8933b_row8_col25, #T_8933b_row8_col26, #T_8933b_row8_col27, #T_8933b_row8_col28, #T_8933b_row8_col29, #T_8933b_row8_col30, #T_8933b_row8_col31, #T_8933b_row8_col32, #T_8933b_row8_col33, #T_8933b_row8_col34, #T_8933b_row9_col8, #T_8933b_row9_col21, #T_8933b_row9_col26, #T_8933b_row10_col8, #T_8933b_row10_col21, #T_8933b_row10_col26, #T_8933b_row11_col8, #T_8933b_row11_col21, #T_8933b_row11_col26, #T_8933b_row12_col8, #T_8933b_row12_col21, #T_8933b_row12_col26, #T_8933b_row13_col8, #T_8933b_row13_col21, #T_8933b_row13_col26, #T_8933b_row14_col8, #T_8933b_row14_col21, #T_8933b_row14_col26, #T_8933b_row15_col8, #T_8933b_row15_col21, #T_8933b_row15_col26, #T_8933b_row16_col8, #T_8933b_row16_col21, #T_8933b_row16_col26, #T_8933b_row17_col8, #T_8933b_row17_col21, #T_8933b_row17_col26, #T_8933b_row18_col8, #T_8933b_row18_col21, #T_8933b_row18_col26, #T_8933b_row19_col8, #T_8933b_row19_col21, #T_8933b_row19_col26, #T_8933b_row20_col8, #T_8933b_row20_col21, #T_8933b_row20_col26, #T_8933b_row21_col0, #T_8933b_row21_col1, #T_8933b_row21_col2, #T_8933b_row21_col3, #T_8933b_row21_col4, #T_8933b_row21_col5, #T_8933b_row21_col6, #T_8933b_row21_col7, #T_8933b_row21_col8, #T_8933b_row21_col9, #T_8933b_row21_col10, #T_8933b_row21_col11, #T_8933b_row21_col12, #T_8933b_row21_col13, #T_8933b_row21_col14, #T_8933b_row21_col15, #T_8933b_row21_col16, #T_8933b_row21_col17, #T_8933b_row21_col18, #T_8933b_row21_col19, #T_8933b_row21_col20, #T_8933b_row21_col21, #T_8933b_row21_col22, #T_8933b_row21_col23, #T_8933b_row21_col24, #T_8933b_row21_col25, #T_8933b_row21_col26, #T_8933b_row21_col27, #T_8933b_row21_col28, #T_8933b_row21_col29, #T_8933b_row21_col30, #T_8933b_row21_col31, #T_8933b_row21_col32, #T_8933b_row21_col33, #T_8933b_row21_col34, #T_8933b_row22_col8, #T_8933b_row22_col21, #T_8933b_row22_col26, #T_8933b_row23_col8, #T_8933b_row23_col21, #T_8933b_row23_col26, #T_8933b_row24_col8, #T_8933b_row24_col21, #T_8933b_row24_col26, #T_8933b_row25_col8, #T_8933b_row25_col21, #T_8933b_row25_col26, #T_8933b_row26_col0, #T_8933b_row26_col1, #T_8933b_row26_col2, #T_8933b_row26_col3, #T_8933b_row26_col4, #T_8933b_row26_col5, #T_8933b_row26_col6, #T_8933b_row26_col7, #T_8933b_row26_col8, #T_8933b_row26_col9, #T_8933b_row26_col10, #T_8933b_row26_col11, #T_8933b_row26_col12, #T_8933b_row26_col13, #T_8933b_row26_col14, #T_8933b_row26_col15, #T_8933b_row26_col16, #T_8933b_row26_col17, #T_8933b_row26_col18, #T_8933b_row26_col19, #T_8933b_row26_col20, #T_8933b_row26_col21, #T_8933b_row26_col22, #T_8933b_row26_col23, #T_8933b_row26_col24, #T_8933b_row26_col25, #T_8933b_row26_col26, #T_8933b_row26_col27, #T_8933b_row26_col28, #T_8933b_row26_col29, #T_8933b_row26_col30, #T_8933b_row26_col31, #T_8933b_row26_col32, #T_8933b_row26_col33, #T_8933b_row26_col34, #T_8933b_row27_col8, #T_89

# %%
df_temp = df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis=1)

# %%
corr_JS = df_temp.drop(['EnvironmentSatisfaction', 'Attrition'], axis=1).corrwith(df.JobSatisfaction)
corr_JS
# Out:
# Age                        -0.004892
# BusinessTravel             -0.033962
# DailyRate                   0.030571
# Department                  0.021001
# DistanceFromHome           -0.003669
# Education                  -0.011296
# EducationField             -0.034401
# Gender                      0.033252
# HourlyRate                 -0.071335
# JobInvolvement             -0.021476
# JobLevel                   -0.001944
# JobRole                     0.017537
# JobSatisfaction             1.000000
# MaritalStatus               0.024360
# MonthlyIncome              -0.007157
# MonthlyRate                 0.000644
# NumCompaniesWorked         -0.055699
# OverTime                    0.024539
# PercentSalaryHike           0.020002
# PerformanceRating           0.002297
# RelationshipSatisfaction   -0.012454
# StockOptionLevel            0.010690
# TotalWorkingYears          -0.020185
# TrainingTimesLastYear      -0.005779
# WorkLifeBalance            -0.019459
# YearsAtCompany             -0.003803
# YearsInCurrentRole         -0.002305
# YearsSinceLastPromotion    -0.018214
# YearsWithCurrManager       -0.027656
# dtype: float64

# %%
corr_ES = df_temp.drop(['JobSatisfaction', 'Attrition'], axis=1).corrwith(df.EnvironmentSatisfaction)
corr_ES
# Out:
# Age                         0.010146
# BusinessTravel              0.004174
# DailyRate                   0.018355
# Department                 -0.019395
# DistanceFromHome           -0.016075
# Education                  -0.027128
# EducationField              0.043163
# EnvironmentSatisfaction     1.000000
# Gender                      0.000508
# HourlyRate                 -0.049857
# JobInvolvement             -0.008278
# JobLevel                    0.001212
# JobRole                    -0.017321
# MaritalStatus              -0.003593
# MonthlyIncome              -0.006259
# MonthlyRate                 0.037600
# NumCompaniesWorked          0.012594
# OverTime                    0.070132
# PercentSalaryHike          -0.031701
# PerformanceRating          -0.029548
# RelationshipSatisfaction    0.007665
# StockOptionLevel            0.003432
# TotalWorkingYears          -0.002693
# TrainingTimesLastYear      -0.019359
# WorkLifeBalance             0.027627
# YearsAtCompany              0.001458
# YearsInCurrentRole          0.018007
# YearsSinceLastPromotion     0.016194
# YearsWithCurrManager       -0.004999
# dtype: float64

# %%
corr_A = df_temp.drop(['JobSatisfaction', 'EnvironmentSatisfaction'], axis=1).corrwith(df.Attrition)
corr_A
# Out:
# Age                        -0.159205
# Attrition                   1.000000
# BusinessTravel              0.000074
# DailyRate                  -0.056652
# Department                  0.063991
# DistanceFromHome            0.077924
# Education                  -0.031373
# EducationField              0.026846
# Gender                      0.029453
# HourlyRate                 -0.006846
# JobInvolvement             -0.130016
# JobLevel                   -0.169105
# JobRole                     0.067151
# MaritalStatus               0.162070
# MonthlyIncome              -0.159840
# MonthlyRate                 0.015170
# NumCompaniesWorked          0.043494
# OverTime                    0.246118
# PercentSalaryHike          -0.013478
# PerformanceRating           0.002889
# RelationshipSatisfaction   -0.045872
# StockOptionLevel           -0.137145
# TotalWorkingYears          -0.171063
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# YearsAtCompany             -0.134392
# YearsInCurrentRole         -0.160545
# YearsSinceLastPromotion    -0.033019
# YearsWithCurrManager       -0.156199
# dtype: float64

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

sel = SelectFromModel(Lasso(alpha=0.005, random_state=42))
sel.fit(X, Y_JS)
print("Job Statisfaction", sel.get_support())
print("Selected Features", X.columns[sel.get_support()])
X_JS = X[X.columns[sel.get_support()]]

sel = SelectFromModel(Lasso(alpha=0.005, random_state=42))
sel.fit(X, Y_ES)
print("\n\nEmployee Statisfaction", sel.get_support())
print("Selected Features", X.columns[sel.get_support()])
X_ES = X[X.columns[sel.get_support()]]


sel = SelectFromModel(Lasso(alpha=0.005, random_state=42))
sel.fit(X, Y_A)
print("\n\nAttrition", sel.get_support())
print("Selected Features", X.columns[sel.get_support()])
X_A = X[X.columns[sel.get_support()]]
# Out:
# Job Statisfaction [ True  True  True  True  True False  True False  True  True  True  True
#   True  True  True False False  True False  True  True False  True False
#   True  True  True  True  True  True  True  True]
# Selected Features Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
#
#
# Employee Statisfaction [ True False  True  True  True  True  True False  True False  True False
#   True  True False False False  True False  True  True False False False
#  False  True  True  True  True  True  True  True]
# Selected Features Index(['Age', 'DailyRate', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EmployeeNumber', 'HourlyRate', 'JobLevel', 'JobRole',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
#
#
# Attrition [ True False  True  True  True False  True False False  True False  True
#  False  True  True False False  True False  True  True False  True False
#   True  True  True  True  True  True  True  True]
# Selected Features Index(['Age', 'DailyRate', 'Department', 'DistanceFromHome', 'EducationField',
#        'Gender', 'JobInvolvement', 'JobRole', 'MaritalStatus',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_JS_train, X_JS_test, Y_JS_train, Y_JS_test = train_test_split(X_JS, Y_JS, test_size=0.2, random_state=42, stratify=Y_JS)
X_ES_train, X_ES_test, Y_ES_train, Y_ES_test = train_test_split(X_ES, Y_ES, test_size=0.2, random_state=42, stratify=Y_ES)
X_A_train, X_A_test, Y_A_train, Y_A_test = train_test_split(X_A, Y_A, test_size=0.2, random_state=42, stratify=Y_A)

# %%
X_JS_train.to_csv('Dataset/X_JS_train.csv', index=False)
X_JS_test.to_csv('Dataset/X_JS_test.csv', index=False)
Y_JS_train.to_csv('Dataset/Y_JS_train.csv', index=False)
Y_JS_test.to_csv('Dataset/Y_JS_test.csv', index=False)

X_ES_train.to_csv('Dataset/X_ES_train.csv', index=False)
X_ES_test.to_csv('Dataset/X_ES_test.csv', index=False)
Y_ES_train.to_csv('Dataset/Y_ES_train.csv', index=False)
Y_ES_test.to_csv('Dataset/Y_ES_test.csv', index=False)


X_A_train.to_csv('Dataset/X_A_train.csv', index=False)
X_A_test.to_csv('Dataset/X_A_test.csv', index=False)
Y_A_train.to_csv('Dataset/Y_A_train.csv', index=False)
Y_A_test.to_csv('Dataset/Y_A_test.csv', index=False)

# %%
#write a function to create a model for each of the three target variables using pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

def create_model(model, X_train, Y_train, X_test, Y_test, Y_name, name):
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    print("\n\n\n" + Y_name + " " + name + " Model")
    print("Accuracy: ", accuracy_score(Y_test, Y_pred))
    print("Precision: ", precision_score(Y_test, Y_pred, average='macro'))
    print("Recall: ", recall_score(Y_test, Y_pred, average='macro'))
    print("F1 Score: ", f1_score(Y_test, Y_pred, average='macro'))
    print("Confusion Matrix: \n", confusion_matrix(Y_test, Y_pred))
    print("Classification Report: \n", classification_report(Y_test, Y_pred))

# %%
def get_models(model, name):    
    #Job Satisfaction
    model_JS = Pipeline([('scaler', StandardScaler()), ('model', model)])
    create_model(model_JS, X_JS_train, Y_JS_train, X_JS_test, Y_JS_test, "JS", name)

    #Environment Satisfaction
    model_ES = Pipeline([('scaler', StandardScaler()), ('model', model)])
    create_model(model_ES, X_ES_train, Y_ES_train, X_ES_test, Y_ES_test, "ES", name)

    #Attrition
    model_A = Pipeline([('scaler', StandardScaler()), ('model', model)])
    create_model(model_A, X_A_train, Y_A_train, X_A_test, Y_A_test, "A", name)

    return model_JS, model_ES, model_A

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
model_JS_RF, model_ES_RF, model_A_RF = get_models(RandomForestClassifier(n_estimators=200, random_state=42), "Random Forest")
# Out:
# JS Random Forest Model
# Accuracy:  0.2755102040816326
# Precision:  0.22641696229684022
# Recall:  0.23313586713136938
# F1 Score:  0.20669786286766265
# Confusion Matrix:
#  [[ 1  4 25 28]
#  [ 6  4 17 29]
#  [ 6  5 36 41]
#  [ 4  2 46 40]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.06      0.02      0.03        58
#            1       0.27      0.07      0.11        56
#            2       0.29      0.41      0.34        88
#            3       0.29      0.43      0.35        92
#
#     accuracy                           0.28       294
#    macro avg       0.23      0.23      0.21       294
# weighted avg       0.24      0.28      0.24       294
#
#
#
#
# ES Random Forest Model
# Accuracy:  0.30952380952380953
# Precision:  0.28147889102601464
# Recall:  0.2657026100254959
# F1 Score:  0.2423082262689286
# Confusion Matrix:
#  [[ 5  3 22 27]
#  [ 4  3 28 22]
#  [ 5  7 41 38]
#  [ 4  1 42 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.28      0.09      0.13        57
#            1       0.21      0.05      0.08        57
#            2       0.31      0.45      0.37        91
#            3       0.33      0.47      0.39        89
#
#     accuracy                           0.31       294
#    macro avg       0.28      0.27      0.24       294
# weighted avg       0.29      0.31      0.27       294
#
#
#
#
# A Random Forest Model
# Accuracy:  0.8333333333333334
# Precision:  0.6468075539568345
# Recall:  0.5562494616246016
# F1 Score:  0.5644444444444444
# Confusion Matrix:
#  [[238   9]
#  [ 40   7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       247
#            1       0.44      0.15      0.22        47
#
#     accuracy                           0.83       294
#    macro avg       0.65      0.56      0.56       294
# weighted avg       0.79      0.83      0.80       294

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
model_JS_LR, model_ES_LR, model_A_LR = get_models(LogisticRegression(random_state=42), "Logistic Regression")
# Out:
# JS Logistic Regression Model
# Accuracy:  0.2653061224489796
# Precision:  0.2420414698726206
# Recall:  0.2245218705582274
# F1 Score:  0.19660212728019788
# Confusion Matrix:
#  [[ 4  3 23 28]
#  [ 2  1 26 27]
#  [ 7  1 36 44]
#  [ 2  1 52 37]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.27      0.07      0.11        58
#            1       0.17      0.02      0.03        56
#            2       0.26      0.41      0.32        88
#            3       0.27      0.40      0.32        92
#
#     accuracy                           0.27       294
#    macro avg       0.24      0.22      0.20       294
# weighted avg       0.25      0.27      0.23       294
#
#
#
#
# ES Logistic Regression Model
# Accuracy:  0.3163265306122449
# Precision:  0.204158998895841
# Recall:  0.26300355469486164
# F1 Score:  0.21819135562826986
# Confusion Matrix:
#  [[ 3  1 26 27]
#  [ 5  0 27 25]
#  [ 6  1 48 36]
#  [ 5  0 42 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.16      0.05      0.08        57
#            1       0.00      0.00      0.00        57
#            2       0.34      0.53      0.41        91
#            3       0.32      0.47      0.38        89
#
#     accuracy                           0.32       294
#    macro avg       0.20      0.26      0.22       294
# weighted avg       0.23      0.32      0.26       294
#
#
#
#
# A Logistic Regression Model
# Accuracy:  0.8503401360544217
# Precision:  0.717852684144819
# Recall:  0.6352829701093978
# F1 Score:  0.6599011462824692
# Confusion Matrix:
#  [[235  12]
#  [ 32  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       247
#            1       0.56      0.32      0.41        47
#
#     accuracy                           0.85       294
#    macro avg       0.72      0.64      0.66       294
# weighted avg       0.83      0.85      0.83       294

# %%
#AdaBoost Classifier
from sklearn.ensemble import AdaBoostClassifier
model_JS_AB, model_ES_AB, model_A_AB = get_models(AdaBoostClassifier(n_estimators=200, random_state=42), "AdaBoost")
# Out:
# JS AdaBoost Model
# Accuracy:  0.24829931972789115
# Precision:  0.22858734252992785
# Recall:  0.22882430537977766
# F1 Score:  0.2270068456892667
# Confusion Matrix:
#  [[ 7  8 20 23]
#  [ 8  9 18 21]
#  [13 12 29 34]
#  [15 18 31 28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.16      0.12      0.14        58
#            1       0.19      0.16      0.17        56
#            2       0.30      0.33      0.31        88
#            3       0.26      0.30      0.28        92
#
#     accuracy                           0.25       294
#    macro avg       0.23      0.23      0.23       294
# weighted avg       0.24      0.25      0.24       294
#
#
#
#
# ES AdaBoost Model
# Accuracy:  0.24489795918367346
# Precision:  0.23320983608594226
# Recall:  0.23072807342470264
# F1 Score:  0.22915267204900802
# Confusion Matrix:
#  [[ 7 14 12 24]
#  [ 4 12 20 21]
#  [12 16 24 39]
#  [14 14 32 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.19      0.12      0.15        57
#            1       0.21      0.21      0.21        57
#            2       0.27      0.26      0.27        91
#            3       0.26      0.33      0.29        89
#
#     accuracy                           0.24       294
#    macro avg       0.23      0.23      0.23       294
# weighted avg       0.24      0.24      0.24       294
#
#
#
#
# A AdaBoost Model
# Accuracy:  0.8333333333333334
# Precision:  0.6823818897637794
# Recall:  0.6596175381169782
# F1 Score:  0.6694886089889187
# Confusion Matrix:
#  [[226  21]
#  [ 28  19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       247
#            1       0.47      0.40      0.44        47
#
#     accuracy                           0.83       294
#    macro avg       0.68      0.66      0.67       294
# weighted avg       0.82      0.83      0.83       294

# %%
#XGBoost Classifier for multi-class classification
from xgboost import XGBClassifier
model_JS_XGB, model_ES_XGB, model_A_XGB = get_models(XGBClassifier(n_estimators=200, random_state=42), "XGBoost")
# Out:
# JS XGBoost Model
# Accuracy:  0.22448979591836735
# Precision:  0.18098882357657886
# Recall:  0.19444924453357737
# F1 Score:  0.18428794285906291
# Confusion Matrix:
#  [[ 3 10 21 24]
#  [ 8  4 16 28]
#  [15 15 27 31]
#  [ 9  9 42 32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.09      0.05      0.06        58
#            1       0.11      0.07      0.09        56
#            2       0.25      0.31      0.28        88
#            3       0.28      0.35      0.31        92
#
#     accuracy                           0.22       294
#    macro avg       0.18      0.19      0.18       294
# weighted avg       0.20      0.22      0.21       294
#
#
#
#
# ES XGBoost Model
# Accuracy:  0.282312925170068
# Precision:  0.27505177932592734
# Recall:  0.26768791035497125
# F1 Score:  0.26823609448520136
# Confusion Matrix:
#  [[15  3 18 21]
#  [ 6  8 15 28]
#  [17 14 28 32]
#  [ 9 15 33 32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.32      0.26      0.29        57
#            1       0.20      0.14      0.16        57
#            2       0.30      0.31      0.30        91
#            3       0.28      0.36      0.32        89
#
#     accuracy                           0.28       294
#    macro avg       0.28      0.27      0.27       294
# weighted avg       0.28      0.28      0.28       294
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[74], line 3
#       1 #XGBoost Classifier for multi-class classification
#       2 from xgboost import XGBClassifier
# ----> 3 model_JS_XGB, model_ES_XGB, model_A_XGB = get_models(XGBClassifier(n_estimators=200, random_state=42), "XGBoost")
#
# Cell In[68], line 12, in get_models(model, name)
#      10 #Attrition
#      11 model_A = Pipeline([('scaler', StandardScaler()), ('model', model)])
# ---> 12 create_model(model_A, X_A_train, Y_A_train, X_A_test, Y_A_test, "A", name)
#      14 return model_JS, model_ES, model_A
#
# Cell In[67], line 8, in create_model(model, X_train, Y_train, X_test, Y_test, Y_name, name)
#       7 def create_model(model, X_train, Y_train, X_test, Y_test, Y_name, name):
# ----> 8     model.fit(X_train, Y_train)
#       9     Y_pred = model.predict(X_test)
#      10     print("\n\n\n" + Y_name + " " + name + " Model")
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/sklearn/pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/xgboost/sklearn.py:1490, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1462 (
#    1463     model,
#    1464     metric,
#    (...)
#    1469     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1470 )
#    1471 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1472     missing=self.missing,
#    1473     X=X,
#    (...)
#    1487     feature_types=self.feature_types,
#    1488 )
# -> 1490 self._Booster = train(
#    1491     params,
#    1492     train_dmatrix,
#    1493     self.get_num_boosting_rounds(),
#    1494     evals=evals,
#    1495     early_stopping_rounds=early_stopping_rounds,
#    1496     evals_result=evals_result,
#    1497     obj=obj,
#    1498     custom_metric=metric,
#    1499     verbose_eval=verbose,
#    1500     xgb_model=model,
#    1501     callbacks=callbacks,
#    1502 )
#    1504 if not callable(self.objective):
#    1505     self.objective = params["objective"]
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/xgboost/core.py:279, in _check_call(ret)
#     268 """Check the return value of C API call
#     269
#     270 This function will raise exception when error occurs.
#    (...)
#     276     return value from API calls
#     277 """
#     278 if ret != 0:
# --> 279     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: value 0 for Parameter num_class should be greater equal to 1
# num_class: Number of output class in the multi-class classification.
